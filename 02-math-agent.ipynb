# %%
import os

import autogen
from autogen.agentchat.contrib.math_user_proxy_agent import MathUserProxyAgent

config_list = autogen.config_list_from_json(
    "OAI_CONFIG_LIST",
    filter_dict={
        "model": {
            "gpt-4o-mini",
            "gpt-4o",
        }
    },
)

# %%
# 1. create an AssistantAgent instance named "assistant"
assistant = autogen.AssistantAgent(
    name="assistant",
    system_message="You are a helpful assistant.",
    llm_config={
        "timeout": 600,
        "seed": 42,
        "config_list": config_list,
    },
)

# 2. create the MathUserProxyAgent instance named "mathproxyagent"
# By default, the human_input_mode is "NEVER", which means the agent will not ask for human input.
mathproxyagent = MathUserProxyAgent(
    name="mathproxyagent",
    human_input_mode="NEVER",
    code_execution_config={"use_docker": False},
)

# %%
# given a math problem, we use the mathproxyagent to generate a prompt to be sent to the assistant as the initial message.
# the assistant receives the message and generates a response. The response will be sent back to the mathproxyagent for processing.
# The conversation continues until the termination condition is met, in MathChat, the termination condition is the detect of "\boxed{}" in the response.
math_problem = (
    "Find all $x$ that satisfy the inequality $(2x+10)(x+3)<(3x+9)(x+8)$. Express your answer in interval notation."
)

# We call `initiate_chat` to start the conversation.
# When setting `message=mathproxyagent.message_generator`, you need to pass in the problem through the `problem` parameter.
mathproxyagent.initiate_chat(assistant, message=mathproxyagent.message_generator, problem=math_problem)
# Out:
# mathproxyagent (to assistant):
#
# Let's use Python to solve a math problem.
#
# Query requirements:
# You should always use the 'print' function for the output and use fractions/radical forms instead of decimals.
# You can use packages like sympy to help you.
# You must follow the formats below to write your code:
# ```python
# # your code
# ```
#
# First state the key idea to solve the problem. You may choose from three ways to solve the problem:
# Case 1: If the problem can be solved with Python code directly, please write a program to solve it. You can enumerate all possible arrangements if needed.
# Case 2: If the problem is mostly reasoning, you can solve it by yourself directly.
# Case 3: If the problem cannot be handled in the above two ways, please follow this process:
# 1. Solve the problem step by step (do not over-divide the steps).
# 2. Take out any queries that can be asked through Python (for example, any calculations or equations that can be calculated).
# 3. Wait for me to give the results.
# 4. Continue if you think the result is correct. If the result is invalid or unexpected, please correct your query or reasoning.
#
# After all the queries are run and you get the answer, put the answer in \boxed{}.
#
# Problem:
# Find all $x$ that satisfy the inequality $(2x+10)(x+3)<(3x+9)(x+8)$. Express your answer in interval notation.
#
# --------------------------------------------------------------------------------
# assistant (to mathproxyagent):
#
# To solve the inequality \((2x+10)(x+3)<(3x+9)(x+8)\), we can first expand both sides and then rearrange the inequality to isolate all terms on one side.
#
# ### Step 1: Expand both sides of the inequality.
# 1. Left side: \((2x + 10)(x + 3) = 2x^2 + 6x + 10x + 30 = 2x^2 + 16x + 30\)
# 2. Right side: \((3x + 9)(x + 8) = 3x^2 + 24x + 9x + 72 = 3x^2 + 33x + 72\)
#
# ### Step 2: Rearrange the inequality.
# The inequality becomes:
# \[
# 2x^2 + 16x + 30 < 3x^2 + 33x + 72
# \]
# Rearranging gives:
# \[
# 0 < 3x^2 + 33x + 72 - 2x^2 - 16x - 30
# \]
# which simplifies to:
# \[
# 0 < x^2 + 17x + 42
# \]
# or equivalently:
# \[
# x^2 + 17x + 42 > 0
# \]
#
# ### Step 3: Factor the quadratic if possible.
# To factor \(x^2 + 17x + 42\):
# \[
# x^2 + 17x + 42 = (x + 3)(x + 14)
# \]
#
# ### Step 4: Determine the roots.
# The roots of \(x^2 + 17x + 42 = 0\) are:
# \[
# x + 3 = 0 \implies x = -3
# \]
# \[
# x + 14 = 0 \implies x = -14
# \]
#
# ### Step 5: Test intervals to determine where the inequality holds.
# We will test intervals based on the roots \(x = -14\) and \(x = -3\):
# 1. Choose a test point in \( (-\infty, -14) \) (e.g., \( x = -15 \)):
#    \[
#    f(-15) = (-15 + 3)(-15 + 14) = (-12)(-1) = 12 > 0
#    \]
#    So, the inequality is satisfied in \( (-\infty, -14) \).
#
# 2. Choose a test point in \( (-14, -3) \) (e.g., \( x = -10 \)):
#    \[
#    f(-10) = (-10 + 3)(-10 + 14) = (-7)(4) = -28 < 0
#    \]
#    So the inequality is not satisfied in \( (-14, -3) \).
#
# 3. Choose a test point in \( (-3, \infty) \) (e.g., \( x = 0 \)):
#    \[
#    f(0) = (0 + 3)(0 + 14) = (3)(14) = 42 > 0
#    \]
#    So the inequality is satisfied in \( (-3, +\infty) \).
#
# ### Conclusion
# The solution in interval notation is:
# \[
# (-\infty, -14) \cup (-3, \infty)
# \]
#
# Now I will print the result:
# ```python
# # your code
# from sympy import symbols, simplify
#
# x = symbols('x')
# inequality = (x + 3)*(x + 14) > 0
#
# # We can find the intervals where this inequality holds
# answer = '(-∞, -14) ∪ (-3, ∞)'
# print(answer)
# ```
#
# --------------------------------------------------------------------------------
# mathproxyagent (to assistant):
#
# (-∞, -14) ∪ (-3, ∞)
#
# --------------------------------------------------------------------------------
# assistant (to mathproxyagent):
#
# The solution to the inequality \((2x+10)(x+3)<(3x+9)(x+8)\), expressed in interval notation, is:
#
# \[
# \boxed{(-\infty, -14) \cup (-3, \infty)}
# \]
#
# --------------------------------------------------------------------------------
# ChatResult(chat_id=None, chat_history=[{'content': "Let's use Python to solve a math problem.\n\nQuery requirements:\nYou should always use the 'print' function for the output and use fractions/radical forms instead of decimals.\nYou can use packages like sympy to help you.\nYou must follow the formats below to write your code:\n```python\n# your code\n```\n\nFirst state the key idea to solve the problem. You may choose from three ways to solve the problem:\nCase 1: If the problem can be solved with Python code directly, please write a program to solve it. You can enumerate all possible arrangements if needed.\nCase 2: If the problem is mostly reasoning, you can solve it by yourself directly.\nCase 3: If the problem cannot be handled in the above two ways, please follow this process:\n1. Solve the problem step by step (do not over-divide the steps).\n2. Take out any queries that can be asked through Python (for example, any calculations or equations that can be calculated).\n3. Wait for me to give the results.\n4. Continue if you think the result is correct. If the result is invalid or unexpected, please correct your query or reasoning.\n\nAfter all the queries are run and you get the answer, put the answer in \\boxed{}.\n\nProblem:\nFind all $x$ that satisfy the inequality $(2x+10)(x+3)<(3x+9)(x+8)$. Express your answer in interval notation.", 'role': 'assistant', 'name': 'mathproxyagent'}, {'content': "To solve the inequality \\((2x+10)(x+3)<(3x+9)(x+8)\\), we can first expand both sides and then rearrange the inequality to isolate all terms on one side.\n\n### Step 1: Expand both sides of the inequality.\n1. Left side: \\((2x + 10)(x + 3) = 2x^2 + 6x + 10x + 30 = 2x^2 + 16x + 30\\)\n2. Right side: \\((3x + 9)(x + 8) = 3x^2 + 24x + 9x + 72 = 3x^2 + 33x + 72\\)\n\n### Step 2: Rearrange the inequality.\nThe inequality becomes:\n\\[\n2x^2 + 16x + 30 < 3x^2 + 33x + 72\n\\]\nRearranging gives:\n\\[\n0 < 3x^2 + 33x + 72 - 2x^2 - 16x - 30\n\\]\nwhich simplifies to:\n\\[\n0 < x^2 + 17x + 42\n\\]\nor equivalently:\n\\[\nx^2 + 17x + 42 > 0\n\\]\n\n### Step 3: Factor the quadratic if possible.\nTo factor \\(x^2 + 17x + 42\\):\n\\[\nx^2 + 17x + 42 = (x + 3)(x + 14)\n\\]\n\n### Step 4: Determine the roots.\nThe roots of \\(x^2 + 17x + 42 = 0\\) are:\n\\[\nx + 3 = 0 \\implies x = -3\n\\]\n\\[\nx + 14 = 0 \\implies x = -14\n\\]\n\n### Step 5: Test intervals to determine where the inequality holds.\nWe will test intervals based on the roots \\(x = -14\\) and \\(x = -3\\):\n1. Choose a test point in \\( (-\\infty, -14) \\) (e.g., \\( x = -15 \\)):\n   \\[\n   f(-15) = (-15 + 3)(-15 + 14) = (-12)(-1) = 12 > 0\n   \\]\n   So, the inequality is satisfied in \\( (-\\infty, -14) \\).\n\n2. Choose a test point in \\( (-14, -3) \\) (e.g., \\( x = -10 \\)):\n   \\[\n   f(-10) = (-10 + 3)(-10 + 14) = (-7)(4) = -28 < 0\n   \\]\n   So the inequality is not satisfied in \\( (-14, -3) \\).\n\n3. Choose a test point in \\( (-3, \\infty) \\) (e.g., \\( x = 0 \\)):\n   \\[\n   f(0) = (0 + 3)(0 + 14) = (3)(14) = 42 > 0\n   \\]\n   So the inequality is satisfied in \\( (-3, +\\infty) \\).\n\n### Conclusion\nThe solution in interval notation is:\n\\[\n(-\\infty, -14) \\cup (-3, \\infty)\n\\]\n\nNow I will print the result:\n```python\n# your code\nfrom sympy import symbols, simplify\n\nx = symbols('x')\ninequality = (x + 3)*(x + 14) > 0\n\n# We can find the intervals where this inequality holds\nanswer = '(-∞, -14) ∪ (-3, ∞)'\nprint(answer)\n```", 'role': 'user', 'name': 'assistant'}, {'content': '(-∞, -14) ∪ (-3, ∞)', 'role': 'assistant', 'name': 'mathproxyagent'}, {'content': 'The solution to the inequality \\((2x+10)(x+3)<(3x+9)(x+8)\\), expressed in interval notation, is:\n\n\\[\n\\boxed{(-\\infty, -14) \\cup (-3, \\infty)}\n\\]', 'role': 'user', 'name': 'assistant'}], summary='The solution to the inequality \\((2x+10)(x+3)<(3x+9)(x+8)\\), expressed in interval notation, is:\n\n\\[\n\\boxed{(-\\infty, -14) \\cup (-3, \\infty)}\n\\]', cost={'usage_including ...

# %%
# we set the prompt_type to "python", which is a simplified version of the default prompt.
math_problem = "Problem: If $725x + 727y = 1500$ and $729x+ 731y = 1508$, what is the value of $x - y$ ?"
mathproxyagent.initiate_chat(
    assistant, message=mathproxyagent.message_generator, problem=math_problem, prompt_type="python"
)
# Out:
# mathproxyagent (to assistant):
#
# Let's use Python to solve a math problem.
#
# Query requirements:
# You should always use the 'print' function for the output and use fractions/radical forms instead of decimals.
# You can use packages like sympy to help you.
# You must follow the formats below to write your code:
# ```python
# # your code
# ```
#
# Please follow this process:
# 1. Solve the problem step by step (do not over-divide the steps).
# 2. Take out any queries that can be asked through Python (for example, any calculations or equations that can be calculated).
# 3. Wait for me to give the results.
# 4. Continue if you think the result is correct. If the result is invalid or unexpected, please correct your query or reasoning.
#
# After all the queries are run and you get the answer, put the answer in \boxed{}.
#
# Problem: Problem: If $725x + 727y = 1500$ and $729x+ 731y = 1508$, what is the value of $x - y$ ?
#
# --------------------------------------------------------------------------------
# assistant (to mathproxyagent):
#
# To solve the problem step by step, we need to work with the given equations:
#
# 1. The first equation is:
#    \[
#    725x + 727y = 1500
#    \]
#
# 2. The second equation is:
#    \[
#    729x + 731y = 1508
#    \]
#
# Our goal is to find the value of \( x - y \).
#
# ### Step 1: Isolate one of the variables
#
# Let's express \( y \) in terms of \( x \) from the first equation.
#
# Rearranging the first equation for \( y \):
#
# \[
# 727y = 1500 - 725x
# \]
#
# \[
# y = \frac{1500 - 725x}{727}
# \]
#
# ### Step 2: Substitute into the second equation
#
# Now we will substitute \( y \) from the equation we derived into the second equation:
#
# \[
# 729x + 731\left( \frac{1500 - 725x}{727} \right) = 1508
# \]
#
# Now, let's move forward and handle this equation.
#
# ### Step 3: Simplify and solve for \( x \)
#
# We'll multiply through by 727 to eliminate the fraction:
#
# \[
# 727 \cdot 729x + 731(1500 - 725x) = 727 \cdot 1508
# \]
#
# Now, let's evaluate this in Python:
#
# ```python
# from sympy import symbols, Eq, solve
#
# x, y = symbols('x y')
#
# # First equation
# eq1 = Eq(725*x + 727*y, 1500)
# # Second equation
# eq2 = Eq(729*x + 731*y, 1508)
#
# # Solve the system of equations
# solution = solve((eq1, eq2), (x, y))
# solution
# ```
#
# Please execute this code to get the values of \( x \) and \( y \).
#
# --------------------------------------------------------------------------------
# mathproxyagent (to assistant):
#
# {x: -23, y: 25}
#
# --------------------------------------------------------------------------------
# assistant (to mathproxyagent):
#
# Now that we have the values \( x = -23 \) and \( y = 25 \), we can calculate \( x - y \).
#
# ### Step 4: Calculate \( x - y \)
#
# \[
# x - y = -23 - 25
# \]
#
# Let's compute this.
#
# ```python
# # Values of x and y
# x_value = -23
# y_value = 25
#
# # Calculate x - y
# result = x_value - y_value
# result
# ```
#
# Please execute this code to find the value of \( x - y \).
#
# --------------------------------------------------------------------------------
# mathproxyagent (to assistant):
#
# -48
#
# --------------------------------------------------------------------------------
# assistant (to mathproxyagent):
#
# The value we found is:
#
# \[
# x - y = -48
# \]
#
# Thus, the final answer is:
#
# \[
# \boxed{-48}
# \]
#
# --------------------------------------------------------------------------------
# ChatResult(chat_id=None, chat_history=[{'content': "Let's use Python to solve a math problem.\n\nQuery requirements:\nYou should always use the 'print' function for the output and use fractions/radical forms instead of decimals.\nYou can use packages like sympy to help you.\nYou must follow the formats below to write your code:\n```python\n# your code\n```\n\nPlease follow this process:\n1. Solve the problem step by step (do not over-divide the steps).\n2. Take out any queries that can be asked through Python (for example, any calculations or equations that can be calculated).\n3. Wait for me to give the results.\n4. Continue if you think the result is correct. If the result is invalid or unexpected, please correct your query or reasoning.\n\nAfter all the queries are run and you get the answer, put the answer in \\boxed{}.\n\nProblem: Problem: If $725x + 727y = 1500$ and $729x+ 731y = 1508$, what is the value of $x - y$ ?", 'role': 'assistant', 'name': 'mathproxyagent'}, {'content': "To solve the problem step by step, we need to work with the given equations:\n\n1. The first equation is:\n   \\[\n   725x + 727y = 1500\n   \\]\n   \n2. The second equation is:\n   \\[\n   729x + 731y = 1508\n   \\]\n\nOur goal is to find the value of \\( x - y \\).\n\n### Step 1: Isolate one of the variables\n\nLet's express \\( y \\) in terms of \\( x \\) from the first equation. \n\nRearranging the first equation for \\( y \\):\n\n\\[\n727y = 1500 - 725x\n\\]\n\n\\[\ny = \\frac{1500 - 725x}{727}\n\\]\n\n### Step 2: Substitute into the second equation\n\nNow we will substitute \\( y \\) from the equation we derived into the second equation:\n\n\\[\n729x + 731\\left( \\frac{1500 - 725x}{727} \\right) = 1508\n\\]\n\nNow, let's move forward and handle this equation. \n\n### Step 3: Simplify and solve for \\( x \\)\n\nWe'll multiply through by 727 to eliminate the fraction:\n\n\\[\n727 \\cdot 729x + 731(1500 - 725x) = 727 \\cdot 1508\n\\]\n\nNow, let's evaluate this in Python:\n\n```python\nfrom sympy import symbols, Eq, solve\n\nx, y = symbols('x y')\n\n# First equation\neq1 = Eq(725*x + 727*y, 1500)\n# Second equation\neq2 = Eq(729*x + 731*y, 1508)\n\n# Solve the system of equations\nsolution = solve((eq1, eq2), (x, y))\nsolution\n```\n\nPlease execute this code to get the values of \\( x \\) and \\( y \\).", 'role': 'user', 'name': 'assistant'}, {'content': '{x: -23, y: 25}', 'role': 'assistant', 'name': 'mathproxyagent'}, {'content': "Now that we have the values \\( x = -23 \\) and \\( y = 25 \\), we can calculate \\( x - y \\).\n\n### Step 4: Calculate \\( x - y \\)\n\n\\[\nx - y = -23 - 25\n\\]\n\nLet's compute this.\n\n```python\n# Values of x and y\nx_value = -23\ny_value = 25\n\n# Calculate x - y\nresult = x_value - y_value\nresult\n```\n\nPlease execute this code to find the value of \\( x - y \\).", 'role': 'user', 'name': 'assistant'}, {'content': '-48', 'role': 'assistant', 'name': 'mathproxyagent'}, {'content': 'The value we found is:\n\n\\[\nx - y = -48\n\\]\n\nThus, the final answer is:\n\n\\[\n\\boxed{-48}\n\\]', 'role': 'user', 'name': 'assistant'}], summary='The value we found is:\n\n\\[\nx - y = -48\n\\]\n\nThus, the final answer is:\n\n\\[\n\\boxed{-48}\n\\]', cost={'usage_including_cached_inference': {'total_cost': 0.0013154999999999998, 'gpt-4o-mini-2024-07-18': {'cost': 0.0013154999999999998, 'prompt_tokens': 3134, 'completion_tokens': 1409, 'total_tokens': 4543}}, 'usage_excluding_cached_inference': {'total_cost': 0.0013154999999999998, 'gpt-4o-mini-2024-07-18': {'cost': 0.0013154999999999998, 'prompt_tokens': 3134, 'completion_tokens': 1409, 'total_tokens': 4543}}}, human_input=[])
